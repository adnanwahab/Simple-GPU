# %% [markdown]
# First, load the 311 complaints dataset available here https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9

# %%
# download csv 
# filter out all columns except start time, longitude, latitude, complaint type 

CSV_PATH = './311.csv'
import subprocess
from tqdm import tqdm
import pandas as pd 
import os
from h3 import h3
import warnings
warnings.filterwarnings('ignore')

def file_len(fname):
    p = subprocess.Popen(['wc', '-l', fname], stdout=subprocess.PIPE, 
                                              stderr=subprocess.PIPE)
    result, err = p.communicate()
    if p.returncode != 0:
        raise IOError(err)
    return int(result.strip().split()[0])+1

n_rows = file_len(CSV_PATH)
print (f'Exact number of rows: {n_rows}')
df_tmp = pd.read_csv(CSV_PATH, nrows=500)
df_tmp.head()
# Out:
# Exact number of rows: 33297984
#    Unique Key            Created Date             Closed Date Agency  \
# 0    51636006  08/25/2021 11:38:55 PM  08/26/2021 01:56:54 AM   NYPD
# 1    51636007  08/26/2021 12:13:47 AM  08/26/2021 01:28:41 AM   NYPD
# 2    51636008  08/25/2021 09:07:05 PM  08/26/2021 12:37:57 AM   NYPD
# 3    51636009  08/25/2021 10:38:47 PM  08/25/2021 11:19:57 PM   NYPD
# 4    51636010  08/26/2021 12:01:47 AM  08/26/2021 01:11:14 AM   NYPD
#
#                        Agency Name           Complaint Type        Descriptor  \
# 0  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 1  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 2  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 3  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 4  New York City Police Department          Noise - Vehicle    Car/Truck Horn
#
#      Location Type  Incident Zip       Incident Address  ... Vehicle Type  \
# 0  Street/Sidewalk       11211.0    66 KINGSLAND AVENUE  ...          NaN
# 1  Street/Sidewalk       10452.0     1560 JEROME AVENUE  ...          NaN
# 2  Street/Sidewalk       10457.0      220 MT HOPE PLACE  ...          NaN
# 3  Street/Sidewalk       10468.0   2715 GRAND CONCOURSE  ...          NaN
# 4  Street/Sidewalk       11366.0  159-06 UNION TURNPIKE  ...          NaN
#
#   Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 0                  NaN                   NaN                 NaN
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
# 3                  NaN                   NaN                 NaN
# 4                  NaN                   NaN                 NaN
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 0                      NaN       NaN                    NaN  40.718116
# 1                      NaN       NaN                    NaN  40.843809
# 2                      NaN       NaN                    NaN  40.848126
# 3                      NaN       NaN                    NaN  40.868207
# 4                      NaN       NaN                    NaN  40.720353
#
#    Longitude                                 Location
# 0 -73.940376   (40.71811557505409, -73.9403763550395)
# 1 -73.915116  (40.84380862265792, -73.91511574950434)
# 2 -73.904704  (40.84812615021961, -73.90470413791908)
# 3 -73.892766    (40.868206890477, -73.89276565069194)
# 4 -73.807692  (40.72035285789358, -73.80769199878456)
#
# [5 rows x 41 columns]

# %%
import math

types = {
    #'Unique Key': 'float32',
              'Complaint Type': 'category', 
              'Longitude': 'float32',
              'Latitude': 'float32',
#              'Incident Zip': 'int',
              'Created Date': 'str',
#              'Closed Date': 'str',
        }
cols = list(types.keys())
chunksize = 1_000_000

df_list = [] # list to hold the batch dataframe

def process_date(df_chunk, key):
    #df_chunk[key] = df_chunk[key].str.slice(0, 16)
    #print("datetime: \n", pd.to_datetime(df_chunk[key]))
    df_chunk['time'] = pd.to_datetime(df_chunk[key]).astype(int)
    #df_chunk['Complaint Type'] = pd.Categorical(df_chunk['Complaint Type'])
    #df_chunk['Complaint Type'].cat.codes

    
for df_chunk in tqdm(pd.read_csv(CSV_PATH, usecols=cols, dtype=types, chunksize=chunksize)):
    # Neat trick from https://www.kaggle.com/btyuhas/bayesian-optimization-with-xgboost
    # Using parse_dates would be much slower!
    process_date(df_chunk, 'Created Date')
    #df_chunk.drop('Created Date', axis=1, inplace=True)
    #df_chunk.drop('Complaint Type', axis=1, inplace=True)
    #df_chunk.drop('time', axis=1, inplace=True)
    df_list.append(df_chunk) 

#df_list()
pdf = pd.concat(df_list)

# Delete the dataframe list to release memory
del df_list

# See what we have loaded
#pdf.info()
#takes 1:30 minutes
print(123)
# Out:
# 34it [29:58, 52.91s/it]
# 123

# %%
#1 - 16 million = true PNG colors 


pdf.time
# Out:
# 3000000.0

# %%
#split up csv
    
import struct
import json

for i in range(0, 30):
    m = 1000000 * i
    data = flat_list[0:m]

    with open('%s.json'%(str(i)), 'w') as f:
        json.dump(data, f)
        
#     with open('Hello %s!'%(str(i)), 'w', newline='') as outfile:
#         writer = csv.writer(outfile)
    

#df.to_csv('csvfile.csv', encoding='utf-8', index=False)

# with open('your_file.txt', 'w') as f:
#     for line in data:
#         f.write(f"{line}\n")
# packed = map(lambda i: struct.pack("@d", i), data)
# with open("data.bin", "wb") as fh:
#     for i in packed:
#         fh.write(i)

# %%
flat_list = [item for sublist in pdf.values.tolist() for item in sublist]

# %%
flat_list[0:1000]
# Out:
# [40.76512908935547,
#  -73.91952514648438,
#  1.670404237e+18,
#  40.5411491394043,
#  -74.1481704711914,
#  1.670412595e+18,
#  40.685760498046875,
#  -73.77855682373047,
#  1.67040135e+18,
#  40.88101577758789,
#  -73.84993743896484,
#  1.670406576e+18,
#  40.79022979736328,
#  -73.85169982910156,
#  1.670402448e+18,
#  40.684295654296875,
#  -74.00263977050781,
#  1.67035048e+18,
#  40.67268371582031,
#  -73.93997955322266,
#  1.670403904e+18,
#  40.7333984375,
#  -73.84984588623047,
#  1.67033781e+18,
#  40.72842788696289,
#  -73.99537658691406,
#  1.670352566e+18,
#  40.643733978271484,
#  -74.07279205322266,
#  1.670398304e+18,
#  40.72519302368164,
#  -73.87317657470703,
#  1.670403585e+18,
#  40.68113327026367,
#  -73.9492416381836,
#  1.67039847e+18,
#  40.716461181640625,
#  -74.00232696533203,
#  1.670393454e+18,
#  40.65507888793945,
#  -73.87248992919922,
#  1.670388219e+18,
#  40.701454162597656,
#  -73.88081359863281,
#  1.670411893e+18,
#  40.693599700927734,
#  -73.93193817138672,
#  1.670346861e+18,
#  40.68783187866211,
#  -73.9300308227539,
#  1.670337146e+18,
#  40.78333282470703,
#  -73.91792297363281,
#  1.670394655e+18,
#  40.7033576965332,
#  -73.90309143066406,
#  1.670366302e+18,
#  40.67500686645508,
#  -73.8563461303711,
#  1.670401772e+18,
#  40.67955780029297,
#  -73.85613250732422,
#  1.670406154e+18,
#  40.60231018066406,
#  1.670411563e+18,
#  40.818153381347656,
#  -73.89281463623047,
#  1.670412581e+18,
#  40.60187911987305,
#  -74.16532897949219,
#  1.67040378e+18,
#  40.90156173706055,
#  -73.86901092529297,
#  1.67040828e+18,
#  40.881248474121094,
#  -73.86070251464844,
#  1.67040966e+18,
#  40.70203399658203,
#  -73.9541015625,
#  1.670404511e+18,
#  40.636417388916016,
#  -73.91682434082031,
#  1.670369407e+18,
#  40.722251892089844,
#  -74.0035171508789,
#  1.670410466e+18,
#  40.7508659362793,
#  -73.98247528076172,
#  1.670406361e+18,
#  40.67035675048828,
#  -73.98871612548828,
#  1.6704093e+18,
#  40.67595291137695,
#  -74.00119018554688,
#  1.6703796e+18,
#  40.6383056640625,
#  -74.01882934570312,
#  1.670415167e+18,
#  nan,
#  nan,
#  1.670165728e+18,
#  40.73537826538086,
#  -73.95274353027344,
#  1.67041164e+18,
#  40.69649887084961,
#  -73.9805679321289,
#  1.67041224e+18,
#  40.705745697021484,
#  -73.8096923828125,
#  1.67044254e+18,
#  40.74181365966797,
#  -73.919921875,
#  1.6704387e+18,
#  40.757564544677734,
#  -73.90190124511719,
#  1.67041254e+18,
#  40.699188232421875,
#  -73.99398040771484,
#  1.67040612e+18,
#  40.71179962158203,
#  -73.94223022460938,
#  1.6704057e+18,
#  nan,
#  nan,
#  1.67043066e+18,
#  40.59230422973633,
#  -73.97389221191406,
#  1.6704306e+18,
#  40.842586517333984,
#  -73.8664321899414,
#  1.670414853e+18,
#  40.66386032104492,
#  -73.82295989990234,
#  1.6704423e+18,
#  40.7491569519043,
#  -73.86942291259766,
#  1.67037714e+18,
#  40.80527877807617,
#  -73.93359375,
#  1.670408755e+18,
#  40.66157531738281,
#  -73.91547393798828,
#  1.67040828e+18,
#  40.898292541503906,
#  -73.91388702392578,
#  1.67041578e+18,
#  40.86280059814453,
#  -73.92481231689453,
#  1.670407269e+18,
#  40.856239318847656,
#  -73.92886352539062,
#  1.670415409e+18,
#  40.85700225830078,
#  -73.89167785644531,
#  1.67041152e+18,
#  40.70591735839844,
#  -73.89933013916016,
#  1.670395133e+18,
#  40.68120574951172,
#  -73.78842163085938,
#  1.67042369e+18,
#  40.75861740112305,
#  -73.82515716552734,
#  1.670409123e+18,
#  nan,
#  nan,
#  1.670423687e+18,
#  40.73850631713867,
#  -73.9917984008789,
#  1.67038896e+18,
#  40.850860595703125,
#  -73.90764617919922,
#  1.67040144e+18,
#  40.683128356933594,
#  -73.97918701171875,
#  1.67040264e+18,
#  40.7360725402832,
#  -73.77355194091797,
#  1.67041758e+18,
#  40.66645431518555,
#  -73.75762939453125,
#  1.67039748e+18,
#  40.63711929321289,
#  -73.97943115234375,
#  1.670404027e+18,
#  40.85268783569336,
#  -73.88711547851562,
#  1.670407743e+18,
#  40.72730255126953,
#  -73.94607543945312,
#  1.670411393e+18,
#  40.65781021118164,
#  -74.00569915771484,
#  1.670233513e+18,
#  40.53711700439453,
#  -74.16699981689453,
#  1.670263741e+18,
#  40.678375244140625,
#  -73.7938232421875,
#  1.670366723e+18,
#  40.673973083496094,
#  -73.77880859375,
#  1.67045652e+18,
#  40.68500900268555,
#  -73.92948150634766,
#  1.670374662e+18,
#  40.6131706237793,
#  -73.94427490234375,
#  1.670371906e+18,
#  40.739192962646484,
#  -73.8778076171875,
#  1.670374138e+18,
#  40.83301544189453,
#  -73.87732696533203,
#  1.670373994e+18,
#  40.6746711730957,
#  -73.94037628173828,
#  1.670368713e+18,
#  40.82222366333008,
#  -73.901123046875,
#  1.670362727e+18,
#  40.67130661010742,
#  -73.92769622802734,
#  1.670382261e+18,
#  40.744998931884766,
#  -73.8929672241211,
#  1.670362103e+18,
#  40.818153381347656,
#  -73.93865966796875,
#  1.670363281e+18,
#  40.833744049072266,
#  -73.9280776977539,
#  1.670314976e+18,
#  40.67595291137695,
#  -74.00119018554688,
#  1.67044008e+18,
#  40.840850830078125,
#  -73.9373779296875,
#  1.670372993e+18,
#  40.766868591308594,
#  -73.95977783203125,
#  1.67038283e+18,
#  40.81853485107422,
#  -73.94135284423828,
#  1.670380974e+18,
#  40.896846771240234,
#  -73.87480926513672,
#  1.6704081e+18,
#  40.84187698364258,
#  -73.91795349121094,
#  1.670314346e+18,
#  40.8221549987793,
#  -73.8572006225586,
#  1.670311881e+18,
#  nan,
#  nan,
#  1.670325767e+18,
#  nan,
#  nan,
#  1.670344202e+18,
#  40.7706413269043,
#  -73.8980941772461,
#  1.670337943e+18,
#  40.73430252075195,
#  -73.75519561767578,
#  1.670170724e+18,
#  40.763450622558594,
#  -73.74034881591797,
#  1.670166123e+18,
#  nan,
#  nan,
#  1.67025884e+18,
#  40.62862014770508,
#  -74.01805877685547,
#  1.67041686e+18,
#  40.80184555053711,
#  -73.95915222167969,
#  1.67040618e+18,
#  40.69034957885742,
#  -73.84107208251953,
#  1.67044158e+18,
#  40.88971710205078,
#  -73.86380767822266,
#  1.6704108e+18,
#  40.849910736083984,
#  -73.89451599121094,
#  1.670310412e+18,
#  40.828433990478516,
#  -73.88105010986328,
#  1.670247301e+18,
#  40.72694778442383,
#  -73.8644027709961,
#  1.670337854e+18,
#  40.75556945800781,
#  -73.9117660522461,
#  1.67017087e+18,
#  40.69375991821289,
#  -73.90254211425781,
#  1.670167061e+18,
#  nan,
#  nan,
#  1.670247322e+18,
#  40.65978240966797,
#  -73.8829116821289,
#  1.67041988e+18,
#  40.64616012573242,
#  -73.99846649169922,
#  1.670164384e+18,
#  40.760562896728516,
#  -73.9897232055664,
#  1.670374908e+18,
#  40.70793914794922,
#  -73.78374481201172,
#  1.670365428e+18,
#  40.7663688659668,
#  -73.98804473876953,
#  1.670367066e+18,
#  40.853580474853516,
#  -73.904052734375,
#  1.670365586e+18,
#  40.87449264526367,
#  -73.90149688720703,
#  1.670377776e+18,
#  40.805885314941406,
#  -73.94505310058594,
#  1.670395283e+18,
#  40.65736389160156]

# %%
pd.options.display.max_rows = 1000

counts = pdf['Complaint Type'].value_counts()
print(counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ff/8v7sj0716pq8v7tlpkmvj70m0000gn/T/ipykernel_99873/2515456555.py in <module>
# ----> 1 pd.options.display.max_rows = 1000
#       2
#       3 counts = pdf['Complaint Type'].value_counts()
#       4 print(counts)
#       5
#
# NameError: name 'pd' is not defined

# %%
APERTURE_SIZE = 10
hex_col = 'hex'+str(APERTURE_SIZE)


pdf[hex_col] = 0
import json

print(1)
def binRow(df311):
    # find hexs containing the points
    df311[hex_col] = df311.apply(lambda x: h3.geo_to_h3(x.Latitude,x.Longitude,APERTURE_SIZE),1)

    # aggregate the points
    df311g = df311.groupby(hex_col).size()#.to_frame('cnt').reset_index()

    #find center of hex for visualization
#     df311g['lat'] = df311g[hex_col].apply(lambda x: h3.h3_to_geo(x)[0])
#     df311g['lng'] = df311g[hex_col].apply(lambda x: h3.h3_to_geo(x)[1])
    return (df311g)


def saveComplaint(complaint):
    print(complaint)
    data = pdf.loc[pdf['Complaint Type'] ==(complaint)]
    binned = binRow(data)
    complaint = complaint.replace(' ', '-').replace('/','-')
    hi = [(hex, count)  for hex,count in binned.iteritems()]
    with open('./data/'+complaint+'.json', 'w') as outfile: json.dump(hi, outfile)
    
    

stuff = [
    'Noise - Residential',                         
#'HEAT/HOT WATER' ,                              
#'Street Condition'   ,                           
#'Illegal Parking ',                              
#'Blocked Driveway'  ,                            
#'Street Light Condition' ,                       
#'HEATING'          ,                             
#'PLUMBING'     ,                                 
#'Water System'  ,                                
#'Noise - Street/Sidewalk' ,                      
# 'GENERAL CONSTRUCTION'  ,                                                                
#'UNSANITARY CONDITION'
        ]                          


    
    
import csv, json
from geojson import Feature, FeatureCollection, Point, dump


    
def saveComplaint2(complaint):
    
    data = pdf.loc[pdf['Complaint Type'] ==(complaint)]
    binned = binRow(data)
    complaint = complaint.replace(' ', '-').replace('-','')
    print(complaint)
    #[(hex, count)  for hex,count in binned.iteritems()]
    features = []
    for key,val in binned.iteritems():
        
        print(key,val)
        if h3.string_to_h3(key) == 0x0: continue
        else: 
            lat,long = h3.h3_to_geo(key)
            #print(lat, long)
            features.append(
                Feature(
                    geometry = Point((long, lat)),
                    properties = {
                        'noise_value': val,
                        #'created_at': 
                    }
                )
            )
    #return
    print(features[0])
    collection = FeatureCollection(features)
    with open('./data/' + complaint + ".geojson", "w") as f:
        print ('writing to ' + complaint + ".geojson",)
        #f.write('%s' % collection)
        dump(collection, f)

    #with open('./data/'+complaint+'.json', 'w') as outfile: json.dump(hi, outfile)
 
    #     with open(complaint + '.csv', 'w') as csvfile:
    #         reader = csv.reader(csvfile, delimiter=',')
    #         for latitude, longitude, weather, temp in reader:
    #             latitude, longitude = map(float, (latitude, longitude))
          

   

        
for complaint in stuff:
    saveComplaint2(complaint)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ff/8v7sj0716pq8v7tlpkmvj70m0000gn/T/ipykernel_99873/3170813946.py in <module>
#       3
#       4
# ----> 5 pdf[hex_col] = 0
#       6 import json
#       7
#
# NameError: name 'pdf' is not defined

# %% [raw]
# # data = pdf.loc[pdf['Complaint Type'] ==('Noise - Residential')]
# # binned = binRow(data)
# for hex, row in binned.iteritems():
#     print(hex, row)

# %%
#automatically upload all csv to s3
print(50)
# Out:
# 50
